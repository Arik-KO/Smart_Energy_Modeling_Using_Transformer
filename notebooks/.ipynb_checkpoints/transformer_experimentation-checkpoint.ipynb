# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
import numpy as np

# %%
SEQ_LEN = 24
N_FEATURES = 6
D_MODEL = 64
N_HEADS = 4
D_FF = 256
N_LAYERS = 2
DROPOUT = 0.2
