# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import seaborn as sns

# %%
df = pd.read_csv('../data/processed/energy_features_2019.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         8760 non-null   object
#  1   hour         8760 non-null   int64
#  2   avg_energy   8760 non-null   float64
#  3   temperature  8760 non-null   float64
#  4   humidity     8760 non-null   float64
#  5   pressure     8760 non-null   float64
#  6   is_weekend   8760 non-null   int64
#  7   is_holiday   8760 non-null   int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 547.6+ KB

# %%
df.head(5)
# Out:
#          date  hour  avg_energy  temperature  humidity  pressure  is_weekend  \
# 0  2019-01-01     0      1.2825          2.0      80.0    103.12           0
# 1  2019-01-01     1      1.4725          2.0      80.0    103.12           0
# 2  2019-01-01     2      1.1825          1.6      82.0    103.08           0
# 3  2019-01-01     3      1.0875          1.9      79.0    103.12           0
# 4  2019-01-01     4      1.0775          1.9      82.0    103.13           0
#
#    is_holiday
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
sample = df.iloc[:48][['avg_energy', 'temperature', 'humidity',
    'pressure', 'is_weekend', 'is_holiday']].values

# %%
print(sample.shape)
print(sample[:3])
# Out:
# (48, 6)
# [[  1.2825   2.      80.     103.12     0.       1.    ]
#  [  1.4725   2.      80.     103.12     0.       1.    ]
#  [  1.1825   1.6     82.     103.08     0.       1.    ]]

# %%
type(sample)
# Out:
# numpy.ndarray

# %%
sample_t = torch.tensor(sample)

# %%
sample_t = sample_t.float()

# %%
sample_t.dtype
# Out:
# torch.float32

# %%
sample_t = sample_t.unsqueeze(0)
sample_t.shape
# Out:
# torch.Size([1, 48, 6])

# %%
d_model = 8
n_features = 6

embedding_layer = nn.Linear(n_features, d_model, bias = False)

embedded = embedding_layer(sample_t)

print(embedded.shape)
# Out:
# torch.Size([1, 48, 8])

# %%
embedding_layer.weight.shape
# Out:
# torch.Size([8, 6])

# %%
embedding_layer.weight
# Out:
# Parameter containing:
# tensor([[ 0.1023, -0.3253,  0.0516, -0.0640, -0.2760,  0.3341],
#         [ 0.3560, -0.2508, -0.3307,  0.0678,  0.2379,  0.3799],
#         [ 0.3263,  0.1821,  0.1941,  0.0752, -0.1818,  0.0255],
#         [ 0.3117,  0.0853,  0.2082,  0.3291,  0.3924,  0.2089],
#         [-0.3714,  0.3801, -0.1711, -0.3124,  0.3971, -0.1790],
#         [-0.3888, -0.1331,  0.1431,  0.0973, -0.3484, -0.3314],
#         [-0.1464, -0.0720,  0.1490,  0.0770, -0.0507,  0.3113],
#         [ 0.1759,  0.3837,  0.1715,  0.2807, -0.0022, -0.3694]],
#        requires_grad=True)

# %%
embedded[0,:4,5:9]
# Out:
# tensor([[20.3847, 19.8358, 43.2872],
#         [20.3108, 19.8080, 43.3206],
#         [20.7592, 20.1741, 43.4480],
#         [20.3307, 19.7226, 43.0430]], grad_fn=<SliceBackward0>)

# %%
T = 48
pe = torch.zeros(T, d_model)

# %%
position = torch.arange(0, T).unsqueeze(1).float()

# %%
div_term = torch.exp(torch.arange(0,d_model, 2).float() * (-math.log(10000.0)/d_model) )

# %%
div_term.shape
# Out:
# torch.Size([4])

# %%
pe[:, 0::2] = torch.sin(position * div_term)
pe[:, 1::2] = torch.cos(position * div_term)

# %%
print(pe.shape)
print(pe[:4])
# Out:
# torch.Size([48, 8])
# tensor([[ 0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,
#           1.0000e+00,  0.0000e+00,  1.0000e+00],
#         [ 8.4147e-01,  5.4030e-01,  9.9833e-02,  9.9500e-01,  9.9998e-03,
#           9.9995e-01,  1.0000e-03,  1.0000e+00],
#         [ 9.0930e-01, -4.1615e-01,  1.9867e-01,  9.8007e-01,  1.9999e-02,
#           9.9980e-01,  2.0000e-03,  1.0000e+00],
#         [ 1.4112e-01, -9.8999e-01,  2.9552e-01,  9.5534e-01,  2.9995e-02,
#           9.9955e-01,  3.0000e-03,  1.0000e+00]])

# %%
# alternate way
pe2 = torch.zeros(T, d_model)
for t in range(T):
    for i in range(d_model//2):

        denominator = 10000 ** (2*i/d_model)
        pe2[t, 2*i] = math.sin(t * denominator)
        pe2[t, 2*i+1] = math.cos(t * denominator)

print(pe2.shape)
print(pe2[:4])
# Out:
# torch.Size([48, 8])
# tensor([[ 0.0000,  1.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000,  1.0000],
#         [ 0.8415,  0.5403, -0.5440, -0.8391, -0.5064,  0.8623,  0.8269,  0.5624],
#         [ 0.9093, -0.4161,  0.9129,  0.4081, -0.8733,  0.4872,  0.9300, -0.3675],
#         [ 0.1411, -0.9900, -0.9880,  0.1543, -0.9998, -0.0221,  0.2192, -0.9757]])

# %%
print(torch.allclose(pe, pe2))
# Out:
# False
